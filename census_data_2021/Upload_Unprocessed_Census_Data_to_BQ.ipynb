# %%
import requests
from pathlib import Path
import pandas as pd
import zipfile
import os
from google.cloud import bigquery
import shutil

# %%
# URL of the ZIP file
url = 'https://www12.statcan.gc.ca/census-recensement/2021/dp-pd/prof/details/download-telecharger/comp/GetFile.cfm?Lang=E&FILETYPE=CSV&GEONO=006_Ontario'

# Path where you want to save the ZIP file
output_path = Path('census_data.zip')

# Downloading the ZIP file
response = requests.get(url)
output_path.write_bytes(response.content)
# Out:
# 757020277

# %%
# Unzipping the file
with zipfile.ZipFile(output_path, 'r') as zip_ref:
    zip_ref.extractall('census_data')

# %%
file_path = 'census_data/98-401-X2021006_English_CSV_data_Ontario.csv'

# read 100000 CSV file with ISO-8859-1 encoding
df = pd.read_csv(file_path,nrows = 100000, encoding='ISO-8859-1')
# Out:
# /var/tmp/ipykernel_9174/3484019009.py:4: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path,nrows = 100000, encoding='ISO-8859-1')

# %%
df.shape
# Out:
# (100000, 23)

# %%
filtered_df = df[df['GEO_LEVEL'] == 'Dissemination area']

# %%
filtered_df.shape
# Out:
# (86845, 23)

# %%
print(os.getcwd())
# Out:
# /home/jupyter/row_community_database/census_data_2021

# %%
import pandas as pd
from google.cloud import bigquery

# Set your BigQuery and CSV settings
project_id = 'row-community-database'
dataset_name = 'unprocessed'
table_name = 'census2021'
csv_file_path = 'census_data/98-401-X2021006_English_CSV_data_Ontario.csv'
chunksize = 100000  # so that we don't have to read entire CSV in the memory

# Specify the columns you want to read from the CSV
selected_columns = ['DGUID','GEO_LEVEL','GEO_NAME', 'CHARACTERISTIC_NAME', 'C1_COUNT_TOTAL','C10_RATE_TOTAL']

# Construct a BigQuery client object
client = bigquery.Client(project=project_id)

# Define your table ID
table_id = f'{project_id}.{dataset_name}.{table_name}'

# Define the job configuration for BigQuery
job_config = bigquery.LoadJobConfig(
    write_disposition=bigquery.WriteDisposition.WRITE_APPEND,  # Append to the table
    autodetect=True,  # Auto-detect schema
    source_format=bigquery.SourceFormat.CSV,  # The source format is CSV
)

# Encoding type
encoding = 'ISO-8859-1'  # Adjust this based on your CSV's encoding

# Process the CSV file in chunks
for chunk_index, chunk in enumerate(pd.read_csv(csv_file_path, chunksize=chunksize, encoding=encoding, usecols=selected_columns, low_memory=False)):
    
    # Filter the chunk to only include rows where GEO_LEVEL equals "Dissemination area"
    filtered_chunk = chunk[chunk['GEO_LEVEL'] == 'Dissemination area']
    
    # If the filtered chunk is empty, skip to the next chunk
    if filtered_chunk.empty:
        print(f'Chunk {chunk_index} is empty after filtering.')
        continue
    
    try:
        # Load the filtered chunk into BigQuery
        job = client.load_table_from_dataframe(filtered_chunk, table_id, job_config=job_config)
        job.result()  # Wait for the job to complete

        print(f'Loaded chunk {chunk_index} with {len(filtered_chunk)} rows.')
    except Exception as e:
        print(f'Error loading chunk {chunk_index}: {e}')
# Out:
# Loaded chunk 0 with 86845 rows.
# Loaded chunk 1 with 97369 rows.
# Loaded chunk 2 with 97369 rows.
# Loaded chunk 3 with 100000 rows.
# Loaded chunk 4 with 97369 rows.
# Loaded chunk 5 with 94738 rows.
# Loaded chunk 6 with 94584 rows.
# Loaded chunk 7 with 92261 rows.
# Loaded chunk 8 with 92107 rows.
# Loaded chunk 9 with 97149 rows.
# Loaded chunk 10 with 92327 rows.
# Loaded chunk 11 with 100000 rows.
# Loaded chunk 12 with 100000 rows.
# Loaded chunk 13 with 100000 rows.
# Loaded chunk 14 with 100000 rows.
# Loaded chunk 15 with 100000 rows.
# Loaded chunk 16 with 100000 rows.
# Loaded chunk 17 with 100000 rows.
# Loaded chunk 18 with 100000 rows.
# Loaded chunk 19 with 100000 rows.
# Loaded chunk 20 with 100000 rows.
# Loaded chunk 21 with 100000 rows.
# Loaded chunk 22 with 100000 rows.
# Loaded chunk 23 with 100000 rows.
# Loaded chunk 24 with 100000 rows.
# Loaded chunk 25 with 100000 rows.
# Loaded chunk 26 with 100000 rows.
# Loaded chunk 27 with 100000 rows.
# Loaded chunk 28 with 100000 rows.
# Loaded chunk 29 with 100000 rows.
# Loaded chunk 30 with 100000 rows.
# Loaded chunk 31 with 100000 rows.
# Loaded chunk 32 with 100000 rows.
# Loaded chunk 33 with 100000 rows.
# Loaded chunk 34 with 100000 rows.
# Loaded chunk 35 with 100000 rows.
# Loaded chunk 36 with 100000 rows.
# Loaded chunk 37 with 100000 rows.
# Loaded chunk 38 with 100000 rows.
# Loaded chunk 39 with 100000 rows.
# Loaded chunk 40 with 100000 rows.
# Loaded chunk 41 with 100000 rows.
# Loaded chunk 42 with 100000 rows.
# Loaded chunk 43 with 100000 rows.
# Loaded chunk 44 with 100000 rows.
# Loaded chunk 45 with 100000 rows.
# Loaded chunk 46 with 100000 rows.
# Loaded chunk 47 with 92107 rows.
# Loaded chunk 48 with 92107 rows.
# Loaded chunk 49 with 100000 rows.
# Loaded chunk 50 with 92107 rows.
# Loaded chunk 51 with 89476 rows.
# Loaded chunk 52 with 89476 rows.
# Loaded chunk 53 with 94738 rows.
# Loaded chunk 54 with 92107 rows.
# Loaded chunk 55 with 89476 rows.
# Loaded chunk 56 with 97369 rows.
# Loaded chunk 57 with 100000 rows.
# Loaded chunk 58 with 100000 rows.
# Loaded chunk 59 with 100000 rows.
# Loaded chunk 60 with 100000 rows.
# Loaded chunk 61 with 94738 rows.
# Loaded chunk 62 with 92107 rows.
# Loaded chunk 63 with 94738 rows.
# Loaded chunk 64 with 86845 rows.
# Loaded chunk 65 with 97369 rows.
# Loaded chunk 66 with 100000 rows.
# Loaded chunk 67 with 97369 rows.
# Loaded chunk 68 with 100000 rows.
# Loaded chunk 69 with 92107 rows.
# Loaded chunk 70 with 76321 rows.
# Loaded chunk 71 with 94738 rows.
# Loaded chunk 72 with 92107 rows.
# Loaded chunk 73 with 94738 rows.
# Loaded chunk 74 with 97369 rows.
# Loaded chunk 75 with 94738 rows.
# Loaded chunk 76 with 89476 rows.
# Loaded chunk 77 with 92107 rows.
# Loaded chunk 78 with 100000 rows.
# Loaded chunk 79 with 100000 rows.
# Loaded chunk 80 with 100000 rows.
# Loaded chunk 81 with 94738 rows.
# Loaded chunk 82 with 84214 rows.
# Loaded chunk 83 with 100000 rows.
# Loaded chunk 84 with 100000 rows.
# Loaded chunk 85 with 94738 rows.
# Loaded chunk 86 with 100000 rows.
# Loaded chunk 87 with 100000 rows.
# Loaded chunk 88 with 100000 rows.
# Loaded chunk 89 with 97369 rows.
# Loaded chunk 90 with 100000 rows.
# Loaded chunk 91 with 100000 rows.
# Loaded chunk 92 with 100000 rows.
# Loaded chunk 93 with 100000 rows.
# Loaded chunk 94 with 97369 rows.
# Loaded chunk 95 with 100000 rows.
# Loaded chunk 96 with 100000 rows.
# Loaded chunk 97 with 100000 rows.
# Loaded chunk 98 with 100000 rows.
# Loaded chunk 99 with 97369 rows.
# Loaded chunk 100 with 100000 rows.
# Loaded chunk 101 with 100000 rows.
# Loaded chunk 102 with 100000 rows.
# Loaded chunk 103 with 100000 rows.
# Loaded chunk 104 with 100000 rows.
# Loaded chunk 105 with 100000 rows.
# Loaded chunk 106 with 97369 rows.
# Loaded chunk 107 with 100000 rows.
# Loaded chunk 108 with 100000 rows.
# Loaded chunk 109 with 100000 rows.
# Loaded chunk 110 with 97369 rows.
# Loaded chunk 111 with 92107 rows.
# Loaded chunk 112 with 94738 rows.
# Loaded chunk 113 with 100000 rows.
# Loaded chunk 114 with 100000 rows.
# Loaded chunk 115 with 100000 rows.
# Loaded chunk 116 with 100000 rows.
# Loaded chunk 117 with 100000 rows.
# Loaded chunk 118 with 100000 rows.
# Loaded chunk 119 with 100000 rows.
# Loaded chunk 120 with 97369 rows.
# Loaded chunk 121 with 100000 rows.
# Loaded chunk 122 with 100000 rows.
# Loaded chunk 123 with 100000 rows.
# Loaded chunk 124 with 100000 rows.
# Loaded chunk 125 with 100000 rows.
# Loaded chunk 126 with 100000 rows.
# Loaded chunk 127 with 100000 rows.
# Loaded chunk 128 with 100000 rows.
# Loaded chunk 129 with 97369 rows.
# Loaded chunk 130 with 100000 rows.
# Loaded chunk 131 with 100000 rows.
# Loaded chunk 132 with 100000 rows.
# Loaded chunk 133 with 100000 rows.
# Loaded chunk 134 with 97369 rows.
# Loaded chunk 135 with 97369 rows.
# Loaded chunk 136 with 100000 rows.
# Loaded chunk 137 with 97369 rows.
# Loaded chunk 138 with 100000 rows.
# Loaded chunk 139 with 100000 rows.
# Loaded chunk 140 with 97369 rows.
# Loaded chunk 141 with 97369 rows.
# Loaded chunk 142 with 97369 rows.
# Loaded chunk 143 with 97369 rows.
# Loaded chunk 144 with 94738 rows.
# Loaded chunk 145 with 100000 rows.
# Loaded chunk 146 with 100000 rows.
# Loaded chunk 147 with 100000 rows.
# Loaded chunk 148 with 100000 rows.
# Loaded chunk 149 with 100000 rows.
# Loaded chunk 150 with 100000 rows.
# Loaded chunk 151 with 100000 rows.
# Loaded chunk 152 with 100000 rows.
# Loaded chunk 153 with 100000 rows.
# Loaded chunk 154 with 100000 rows.
# Loaded chunk 155 with 100000 rows.
# Loaded chunk 156 with 100000 rows.
# Loaded chunk 157 with 100000 rows.
# Loaded chunk 158 with 100000 rows.
# Loaded chunk 159 with 100000 rows.
# Loaded chunk 160 with 100000 rows.
# Loaded chunk 161 with 100000 rows.
# Loaded chunk 162 with 100000 rows.
# Loaded chunk 163 with 100000 rows.
# Loaded chunk 164 with 100000 rows.
# Loaded chunk 165 with 100000 rows.
# Loaded chunk 166 with 100000 rows.
# Loaded chunk 167 with 100000 rows.
# Loaded chunk 168 with 100000 rows.
# Loaded chunk 169 with 100000 rows.
# Loaded chunk 170 with 100000 rows.
# Loaded chunk 171 with 100000 rows.
# Loaded chunk 172 with 100000 rows.
# Loaded chunk 173 with 100000 rows.
# Loaded chunk 174 with 100000 rows.
# Loaded chunk 175 with 100000 rows.
# Loaded chunk 176 with 100000 rows.
# Loaded chunk 177 with 100000 rows.
# Loaded chunk 178 with 100000 rows.
# Loaded chunk 179 with 100000 rows.
# Loaded chunk 180 with 100000 rows.
# Loaded chunk 181 with 100000 rows.
# Loaded chunk 182 with 100000 rows.
# Loaded chunk 183 with 100000 rows.
# Loaded chunk 184 with 100000 rows.
# Loaded chunk 185 with 100000 rows.
# Loaded chunk 186 with 100000 rows.
# Loaded chunk 187 with 100000 rows.
# Loaded chunk 188 with 100000 rows.
# Loaded chunk 189 with 100000 rows.
# Loaded chunk 190 with 100000 rows.
# Loaded chunk 191 with 100000 rows.
# Loaded chunk 192 with 100000 rows.
# Loaded chunk 193 with 100000 rows.
# Loaded chunk 194 with 100000 rows.
# Loaded chunk 195 with 100000 rows.
# Loaded chunk 196 with 100000 rows.
# Loaded chunk 197 with 100000 rows.
# Loaded chunk 198 with 100000 rows.
# Loaded chunk 199 with 100000 rows.
# Loaded chunk 200 with 100000 rows.
# Loaded chunk 201 with 100000 rows.
# Loaded chunk 202 with 100000 rows.
# Loaded chunk 203 with 100000 rows.
# Loaded chunk 204 with 100000 rows.
# Loaded chunk 205 with 100000 rows.
# Loaded chunk 206 with 100000 rows.
# Loaded chunk 207 with 100000 rows.
# Loaded chunk 208 with 100000 rows.
# Loaded chunk 209 with 100000 rows.
# Loaded chunk 210 with 100000 rows.
# Loaded chunk 211 with 100000 rows.
# Loaded chunk 212 with 100000 rows.
# Loaded chunk 213 with 100000 rows.
# Loaded chunk 214 with 100000 rows.
# Loaded chunk 215 with 100000 rows.
# Loaded chunk 216 with 100000 rows.
# Loaded chunk 217 with 100000 rows.
# Loaded chunk 218 with 100000 rows.
# Loaded chunk 219 with 100000 rows.
# Loaded chunk 220 with 100000 rows.
# Loaded chunk 221 with 100000 rows.
# Loaded chunk 222 with 100000 rows.
# Loaded chunk 223 with 100000 rows.
# Loaded chunk 224 with 100000 rows.
# Loaded chunk 225 with 100000 rows.
# Loaded chunk 226 with 100000 rows.
# Loaded chunk 227 with 100000 rows.
# Loaded chunk 228 with 100000 rows.
# Loaded chunk 229 with 100000 rows.
# Loaded chunk 230 with 100000 rows.
# Loaded chunk 231 with 100000 rows.
# Loaded chunk 232 with 100000 rows.
# Loaded chunk 233 with 100000 rows.
# Loaded chunk 234 with 100000 rows.
# Loaded chunk 235 with 100000 rows.
# Loaded chunk 236 with 100000 rows.
# Loaded chunk 237 with 100000 rows.
# Loaded chunk 238 with 100000 rows.
# Loaded chunk 239 with 100000 rows.
# Loaded chunk 240 with 100000 rows.
# Loaded chunk 241 with 100000 rows.
# Loaded chunk 242 with 94738 rows.
# Loaded chunk 243 with 100000 rows.
# Loaded chunk 244 with 100000 rows.
# Loaded chunk 245 with 100000 rows.
# Loaded chunk 246 with 100000 rows.
# Loaded chunk 247 with 100000 rows.
# Loaded chunk 248 with 100000 rows.
# Loaded chunk 249 with 100000 rows.
# Loaded chunk 250 with 100000 rows.
# Loaded chunk 251 with 100000 rows.
# Loaded chunk 252 with 100000 rows.
# Loaded chunk 253 with 100000 rows.
# Loaded chunk 254 with 100000 rows.
# Loaded chunk 255 with 100000 rows.
# Loaded chunk 256 with 100000 rows.
# Loaded chunk 257 with 100000 rows.
# Loaded chunk 258 with 100000 rows.
# Loaded chunk 259 with 100000 rows.
# Loaded chunk 260 with 100000 rows.
# Loaded chunk 261 with 100000 rows.
# Loaded chunk 262 with 100000 rows.
# Loaded chunk 263 with 100000 rows.
# Loaded chunk 264 with 100000 rows.
# Loaded chunk 265 with 100000 rows.
# Loaded chunk 266 with 100000 rows.
# Loaded chunk 267 with 100000 rows.
# Loaded chunk 268 with 97369 rows.
# Loaded chunk 269 with 100000 rows.
# Loaded chunk 270 with 100000 rows.
# Loaded chunk 271 with 100000 rows.
# Loaded chunk 272 with 100000 rows.
# Loaded chunk 273 with 100000 rows.
# Loaded chunk 274 with 100000 rows.
# Loaded chunk 275 with 100000 rows.
# Loaded chunk 276 with 100000 rows.
# Loaded chunk 277 with 100000 rows.
# Loaded chunk 278 with 100000 rows.
# Loaded chunk 279 with 100000 rows.
# Loaded chunk 280 with 100000 rows.
# Loaded chunk 281 with 100000 rows.
# Loaded chunk 282 with 100000 rows.
# Loaded chunk 283 with 100000 rows.
# Loaded chunk 284 with 100000 rows.
# Loaded chunk 285 with 100000 rows.
# Loaded chunk 286 with 97369 rows.
# Loaded chunk 287 with 100000 rows.
# Loaded chunk 288 with 92107 rows.
# Loaded chunk 289 with 92107 rows.
# Loaded chunk 290 with 97369 rows.
# Loaded chunk 291 with 86845 rows.
# Loaded chunk 292 with 100000 rows.
# Loaded chunk 293 with 100000 rows.
# Loaded chunk 294 with 100000 rows.
# Loaded chunk 295 with 100000 rows.
# Loaded chunk 296 with 100000 rows.
# Loaded chunk 297 with 94738 rows.
# Loaded chunk 298 with 97369 rows.
# Loaded chunk 299 with 97369 rows.
# Loaded chunk 300 with 94738 rows.
# Loaded chunk 301 with 94738 rows.
# Loaded chunk 302 with 100000 rows.
# Loaded chunk 303 with 100000 rows.
# Loaded chunk 304 with 100000 rows.
# Loaded chunk 305 with 100000 rows.
# Loaded chunk 306 with 100000 rows.
# Loaded chunk 307 with 100000 rows.
# Loaded chunk 308 with 100000 rows.
# Loaded chunk 309 with 97369 rows.
# Loaded chunk 310 with 100000 rows.
# Loaded chunk 311 with 100000 rows.
# Loaded chunk 312 with 100000 rows.
# Loaded chunk 313 with 100000 rows.
# Loaded chunk 314 with 100000 rows.
# Loaded chunk 315 with 100000 rows.
# Loaded chunk 316 with 100000 rows.
# Loaded chunk 317 with 97369 rows.
# Loaded chunk 318 with 100000 rows.
# Loaded chunk 319 with 100000 rows.
# Loaded chunk 320 with 97369 rows.
# Loaded chunk 321 with 100000 rows.
# Loaded chunk 322 with 100000 rows.
# Loaded chunk 323 with 94738 rows.
# Loaded chunk 324 with 100000 rows.
# Loaded chunk 325 with 100000 rows.
# Loaded chunk 326 with 100000 rows.
# Loaded chunk 327 with 100000 rows.
# Loaded chunk 328 with 100000 rows.
# Loaded chunk 329 with 100000 rows.
# Loaded chunk 330 with 100000 rows.
# Loaded chunk 331 with 100000 rows.
# Loaded chunk 332 with 100000 rows.
# Loaded chunk 333 with 100000 rows.
# Loaded chunk 334 with 100000 rows.
# Loaded chunk 335 with 100000 rows.
# Loaded chunk 336 with 100000 rows.
# Loaded chunk 337 with 100000 rows.
# Loaded chunk 338 with 100000 rows.
# Loaded chunk 339 with 100000 rows.
# Loaded chunk 340 with 100000 rows.
# Loaded chunk 341 with 100000 rows.
# Loaded chunk 342 with 100000 rows.
# Loaded chunk 343 with 100000 rows.
# Loaded chunk 344 with 100000 rows.
# Loaded chunk 345 with 100000 rows.
# Loaded chunk 346 with 94738 rows.
# Loaded chunk 347 with 100000 rows.
# Loaded chunk 348 with 97369 rows.
# Loaded chunk 349 with 94738 rows.
# Loaded chunk 350 with 94738 rows.
# Loaded chunk 351 with 100000 rows.
# Loaded chunk 352 with 100000 rows.
# Loaded chunk 353 with 97369 rows.
# Loaded chunk 354 with 97369 rows.
# Loaded chunk 355 with 100000 rows.
# Loaded chunk 356 with 100000 rows.
# Loaded chunk 357 with 100000 rows.
# Loaded chunk 358 with 94738 rows.
# Loaded chunk 359 with 100000 rows.
# Loaded chunk 360 with 100000 rows.
# Loaded chunk 361 with 100000 rows.
# Loaded chunk 362 with 100000 rows.
# Loaded chunk 363 with 100000 rows.
# Loaded chunk 364 with 97369 rows.
# Loaded chunk 365 with 97369 rows.
# Loaded chunk 366 with 94738 rows.
# Loaded chunk 367 with 100000 rows.
# Loaded chunk 368 with 94738 rows.
# Loaded chunk 369 with 97369 rows.
# Loaded chunk 370 with 100000 rows.
# Loaded chunk 371 with 100000 rows.
# Loaded chunk 372 with 94738 rows.
# Loaded chunk 373 with 97369 rows.
# Loaded chunk 374 with 100000 rows.
# Loaded chunk 375 with 100000 rows.
# Loaded chunk 376 with 100000 rows.
# Loaded chunk 377 with 100000 rows.
# Loaded chunk 378 with 89476 rows.
# Loaded chunk 379 with 97369 rows.
# Loaded chunk 380 with 100000 rows.
# Loaded chunk 381 with 100000 rows.
# Loaded chunk 382 with 100000 rows.
# Loaded chunk 383 with 100000 rows.
# Loaded chunk 384 with 97369 rows.
# Loaded chunk 385 with 100000 rows.
# Loaded chunk 386 with 100000 rows.
# Loaded chunk 387 with 100000 rows.
# Loaded chunk 388 with 100000 rows.
# Loaded chunk 389 with 100000 rows.
# Loaded chunk 390 with 100000 rows.
# Loaded chunk 391 with 100000 rows.
# Loaded chunk 392 with 97369 rows.
# Loaded chunk 393 with 100000 rows.
# Loaded chunk 394 with 100000 rows.
# Loaded chunk 395 with 100000 rows.
# Loaded chunk 396 with 97369 rows.
# Loaded chunk 397 with 97369 rows.
# Loaded chunk 398 with 97369 rows.
# Loaded chunk 399 with 94738 rows.
# Loaded chunk 400 with 93809 rows.
# Loaded chunk 401 with 93036 rows.
# Loaded chunk 402 with 94738 rows.
# Loaded chunk 403 with 92107 rows.
# Loaded chunk 404 with 94738 rows.
# Loaded chunk 405 with 97369 rows.
# Loaded chunk 406 with 97369 rows.
# Loaded chunk 407 with 92107 rows.
# Loaded chunk 408 with 92107 rows.
# Loaded chunk 409 with 100000 rows.
# Loaded chunk 410 with 94738 rows.
# Loaded chunk 411 with 92107 rows.
# Loaded chunk 412 with 100000 rows.
# Loaded chunk 413 with 100000 rows.
# Loaded chunk 414 with 100000 rows.
# Loaded chunk 415 with 100000 rows.
# Loaded chunk 416 with 100000 rows.
# Loaded chunk 417 with 100000 rows.
# Loaded chunk 418 with 89476 rows.
# Loaded chunk 419 with 97369 rows.
# Loaded chunk 420 with 97369 rows.
# Loaded chunk 421 with 97369 rows.
# Loaded chunk 422 with 97369 rows.
# Loaded chunk 423 with 97369 rows.
# Loaded chunk 424 with 100000 rows.
# Loaded chunk 425 with 100000 rows.
# Loaded chunk 426 with 100000 rows.
# Loaded chunk 427 with 100000 rows.
# Loaded chunk 428 with 100000 rows.
# Loaded chunk 429 with 100000 rows.
# Loaded chunk 430 with 100000 rows.
# Loaded chunk 431 with 100000 rows.
# Loaded chunk 432 with 100000 rows.
# Loaded chunk 433 with 98345 rows.
# Loaded chunk 434 with 96393 rows.
# Loaded chunk 435 with 100000 rows.
# Loaded chunk 436 with 94738 rows.
# Loaded chunk 437 with 84214 rows.
# Loaded chunk 438 with 94738 rows.
# Loaded chunk 439 with 100000 rows.
# Loaded chunk 440 with 100000 rows.
# Loaded chunk 441 with 97369 rows.
# Loaded chunk 442 with 94738 rows.
# Loaded chunk 443 with 84214 rows.
# Loaded chunk 444 with 94738 rows.
# Loaded chunk 445 with 92107 rows.
# Loaded chunk 446 with 97369 rows.
# Loaded chunk 447 with 100000 rows.
# Loaded chunk 448 with 100000 rows.
# Loaded chunk 449 with 100000 rows.
# Loaded chunk 450 with 100000 rows.
# Loaded chunk 451 with 100000 rows.
# Loaded chunk 452 with 100000 rows.
# Loaded chunk 453 with 100000 rows.
# Loaded chunk 454 with 100000 rows.
# Loaded chunk 455 with 100000 rows.
# Loaded chunk 456 with 100000 rows.
# Loaded chunk 457 with 100000 rows.
# Loaded chunk 458 with 100000 rows.
# Loaded chunk 459 with 100000 rows.
# Loaded chunk 460 with 100000 rows.
# Loaded chunk 461 with 97369 rows.
# Loaded chunk 462 with 89476 rows.
# Loaded chunk 463 with 92107 rows.
# Loaded chunk 464 with 94738 rows.
# Loaded chunk 465 with 86845 rows.
# Loaded chunk 466 with 92357 rows.
# Loaded chunk 467 with 94488 rows.
# Loaded chunk 468 with 81583 rows.
# Loaded chunk 469 with 94738 rows.
# Loaded chunk 470 with 94738 rows.
# Loaded chunk 471 with 94738 rows.
# Loaded chunk 472 with 94738 rows.
# Loaded chunk 473 with 94738 rows.
# Loaded chunk 474 with 97369 rows.
# Loaded chunk 475 with 97369 rows.
# Loaded chunk 476 with 97369 rows.
# Loaded chunk 477 with 97369 rows.
# Loaded chunk 478 with 97369 rows.
# Loaded chunk 479 with 97369 rows.
# Loaded chunk 480 with 97369 rows.
# Loaded chunk 481 with 97369 rows.
# Loaded chunk 482 with 97369 rows.
# Loaded chunk 483 with 97369 rows.
# Loaded chunk 484 with 97369 rows.
# Loaded chunk 485 with 100000 rows.
# Loaded chunk 486 with 100000 rows.
# Loaded chunk 487 with 100000 rows.
# Loaded chunk 488 with 100000 rows.
# Loaded chunk 489 with 100000 rows.
# Loaded chunk 490 with 94738 rows.
# Loaded chunk 491 with 100000 rows.
# Loaded chunk 492 with 97369 rows.
# Loaded chunk 493 with 89476 rows.
# Loaded chunk 494 with 94738 rows.
# Loaded chunk 495 with 94738 rows.
# Loaded chunk 496 with 97369 rows.
# Loaded chunk 497 with 94738 rows.
# Loaded chunk 498 with 84214 rows.
# Loaded chunk 499 with 86369 rows.
# Loaded chunk 500 with 84690 rows.
# Loaded chunk 501 with 86845 rows.
# Loaded chunk 502 with 94196 rows.
# Loaded chunk 503 with 92649 rows.
# Loaded chunk 504 with 73690 rows.
# Loaded chunk 505 with 94738 rows.
# Loaded chunk 506 with 100000 rows.
# Loaded chunk 507 with 97369 rows.
# Loaded chunk 508 with 81583 rows.
# Loaded chunk 509 with 73690 rows.
# Loaded chunk 510 with 76321 rows.
# Loaded chunk 511 with 67688 rows.
# Loaded chunk 512 with 66537 rows.
# Loaded chunk 513 with 75537 rows.
# Loaded chunk 514 with 69212 rows.
# Loaded chunk 515 with 92107 rows.
# Loaded chunk 516 with 100000 rows.
# Loaded chunk 517 with 100000 rows.
# Loaded chunk 518 with 100000 rows.
# Loaded chunk 519 with 100000 rows.
# Loaded chunk 520 with 100000 rows.
# Loaded chunk 521 with 100000 rows.
# Loaded chunk 522 with 81583 rows.
# Loaded chunk 523 with 65797 rows.
# Loaded chunk 524 with 78952 rows.
# Loaded chunk 525 with 92107 rows.
# Loaded chunk 526 with 100000 rows.
# Loaded chunk 527 with 83122 rows.
# Loaded chunk 528 with 85306 rows.
# Loaded chunk 529 with 64661 rows.
# Loaded chunk 530 with 66933 rows.
# Loaded chunk 531 with 94738 rows.
# Loaded chunk 532 with 100000 rows.
# Loaded chunk 533 with 100000 rows.
# Loaded chunk 534 with 100000 rows.
# Loaded chunk 535 with 84214 rows.
# Loaded chunk 536 with 78952 rows.
# Loaded chunk 537 with 86845 rows.
# Loaded chunk 538 with 100000 rows.
# Loaded chunk 539 with 100000 rows.
# Loaded chunk 540 with 100000 rows.
# Loaded chunk 541 with 100000 rows.
# Loaded chunk 542 with 97369 rows.
# Loaded chunk 543 with 77508 rows.
# Loaded chunk 544 with 71037 rows.
# Loaded chunk 545 with 78930 rows.
# Loaded chunk 546 with 80440 rows.
# Loaded chunk 547 with 56372 rows.
# Loaded chunk 548 with 72591 rows.
# Loaded chunk 549 with 97369 rows.
# Loaded chunk 550 with 86845 rows.
# Loaded chunk 551 with 68428 rows.
# Loaded chunk 552 with 68428 rows.
# Loaded chunk 553 with 63166 rows.
# Loaded chunk 554 with 79897 rows.
# Loaded chunk 555 with 2631 rows.

# %%
os.remove("census_data.zip")
shutil.rmtree("census_data")
